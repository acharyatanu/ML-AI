# %%
import cv2
import skimage as ski
import matplotlib.pyplot as plt

# %%
img=cv2.imread('lifesaviors.jpg')  #to read a image using opencv library
cv2.imshow('',img)       #to show img
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
img.shape
# Out:
# (640, 640, 3)

# %%
img.shape
# Out:
# (640, 640, 3)

# %%
type(img)
# Out:
# numpy.ndarray

# %%
#opening img from matplotlib

img1=plt.imread('lifesaviors.jpg')
plt.imshow(img1)

# %%
img
# Out:
# array([[[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        ...,
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
#         ...,
#         [255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255]],
#
#        [[255, 255, 255],
#         [255, 255, 255],
#         [255, 255, 255],
# ...
