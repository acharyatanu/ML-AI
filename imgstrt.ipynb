# %%
import cv2
import skimage as ski
import matplotlib.pyplot as plt

# %%
vid = cv2.VideoCapture(0)    #to access the device camera, arg is the device id that is the number of canera device have

# %%
type(vid)
# Out:
# cv2.VideoCapture

# %%
vid.isOpened()    #open cv ne camera ko acquire kr dia
# Out:
# True

# %%
k=vid.read()

# %%
type(k), len(k)   #the 2 values output shows camera is active(bool) and image got is shown with array
# Out:
# (tuple, 2)

# %%
k
# Out:
# (True,
#  array([[[136, 132, 102],
#          [135, 129, 112],
#          [135, 127, 123],
#          ...,
#          [118, 121, 118],
#          [113, 118, 118],
#          [113, 118, 118]],
#
#         [[134, 132, 102],
#          [134, 129, 112],
#          [135, 127, 123],
#          ...,
#          [121, 121, 121],
#          [119, 119, 119],
#          [119, 119, 119]],
#
#         [[135, 128, 120],
#          [135, 128, 121],
#          [135, 128, 122],
#          ...,
#          [121, 121, 121],
#          [120, 120, 120],
#          [119, 119, 119]],
#
#         ...,
#
#         [[131, 140, 142],
#          [130, 137, 153],
#          [130, 134, 166],
#          ...,
#          [122, 113,  84],
#          [125, 114,  85],
#          [125, 113,  85]],
#
#         [[124, 132, 167],
#          [125, 133, 168],
#          [125, 133, 168],
#          ...,
#          [122, 113,  93],
#          [124, 113, 103],
#          [124, 113, 104]],
#
#         [[117, 132, 167],
# ...

# %%
flag,img=vid.read()

# %%
if flag:
    plt.imshow(img)

# %%
#cv2 follows BGR but matplotlib takes it as RGB so the color of the images changes to solve this we reverse the img

img.shape
# Out:
# (480, 640, 3)

# %%
flag, img=vid.read()

# %%
if flag:
    plt.imshow(img[:,:,::-1])

# %%
for i in range(1000):
    flag,img=vid.read()
    if flag:
        cv2.imshow('preview',img)
        cv2.waitKey(1)

# %%
ord('A')  #to get ASCII value of variable we use ord funcn
# Out:
# 65

# %%
#funcn to release camera
vid.release()

# %%
#program snipet to capture some frames of image and than stopping it by pressing a key

vid=cv2.VideoCapture(0)
while True:                              #to have infinte loop
    flag,img=vid.read()
    if flag:
        cv2.imshow('preview',img)
        key=cv2.waitKey(1)
        if key==ord('a'):                 #ASCII value of a is given to key
            break
    else:
          break                           #if camera is not captured than also break
vid.release()
cv2.destroyAllWindows()

# %%
#to have a gray cale img (img_gray)and black and white (img_bw)

vid=cv2.VideoCapture(0)
while True:                              #to have infinte loop
    flag,img=vid.read()
    if flag:
        #Processing code
        img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        th,img_bw=cv2.threshold(img_gray,100,255,cv2.THRESH_BINARY_INV)

        #print(type(img_gray))
        #break
        ##
        cv2.imshow('preview',img_bw)
        key=cv2.waitKey(1)
        if key==ord('a'):                 #ASCII value of a is given to key
            break
    else:
          break                           #if camera is not captured than also break
vid.release()
cv2.destroyAllWindows()

# %%
#to crop the img being shown

vid=cv2.VideoCapture(0)
while True:                              #to have infinte loop
    flag,img=vid.read()
    if flag:
        #Processing code
        img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        th,img_bw=cv2.threshold(img_gray,100,255,cv2.THRESH_BINARY_INV)

        x,y,w,h=(0,0,100,100)
        img_cropped =img[y:y+h,x:x+w,:]

        #print(type(img_gray))
        #break
        ##
        cv2.imshow('preview',img_cropped)
        key=cv2.waitKey(1)
        if key==ord('a'):                 #ASCII value of a is given to key
            break
    else:
          break                           #if camera is not captured than also break
vid.release()
cv2.destroyAllWindows()

# %%
#to create a focus rectangle over the region selected

vid=cv2.VideoCapture(0)
while True:                              #to have infinte loop
    flag,img=vid.read()
    if flag:
        #Processing code
        img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        th,img_bw=cv2.threshold(img_gray,100,255,cv2.THRESH_BINARY_INV)

        x,y,w,h=(250,200,100,100)
        img_cropped =img[y:y+h,x:x+w,:]
        cv2.rectangle(img,pt1=(x,y),pt2=(x+w,y+h),color=(0,0,255),thickness=8)

        #print(type(img_gray))
        #break
        ##
        cv2.imshow('preview',img)
        key=cv2.waitKey(1)
        if key==ord('a'):                 #ASCII value of a is given to key
            break
    else:
          break                           #if camera is not captured than also break
vid.release()
cv2.destroyAllWindows()

# %%
#to detect face 

fd=cv2.CascadeClassifier(cv2.data.haarcascasdes+'haarcascade_frontalface_default.xml')
vid=cv2.VideoCapture(0)
while True:                              #to have infinte loop
    flag,img=vid.read()
    if flag:
        #Processing code
        img_gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
        faces=fd.detectMultiScale(img_gray,1.1,5)
        # th,img_bw=cv2.threshold(img_gray,100,255,cv2.THRESH_BINARY_INV)
        for x,y,w,h in faces:
         #x,y,w,h=(250,200,100,100)
         #img_cropped =img[y:y+h,x:x+w,:]
         cv2.rectangle(img,pt1=(x,y),pt2=(x+w,y+h),color=(0,0,255),thickness=5)

        #print(type(img_gray))
        #break
        ##
        cv2.imshow('preview',img)
        key=cv2.waitKey(1)
        if key==ord('a'):                 #ASCII value of a is given to key
            break
    else:
          break                           #if camera is not captured than also break
vid.release()
cv2.destroyAllWindows()
